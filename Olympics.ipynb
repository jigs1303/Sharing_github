# %%
import pandas as pd

# %%
oo = pd.read_csv(r'C:\Users\Jigs\olympics.csv', skiprows=4)
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo[['City','Edition','Athlete']]
# Out:
#           City  Edition               Athlete
# 0       Athens     1896         HAJOS, Alfred
# 1       Athens     1896      HERSCHMANN, Otto
# 2       Athens     1896     DRIVAS, Dimitrios
# 3       Athens     1896    MALOKINIS, Ioannis
# 4       Athens     1896    CHASAPIS, Spiridon
# ...        ...      ...                   ...
# 29211  Beijing     2008        ENGLICH, Mirko
# 29212  Beijing     2008  MIZGAITIS, Mindaugas
# 29213  Beijing     2008       PATRIKEEV, Yuri
# 29214  Beijing     2008         LOPEZ, Mijain
# 29215  Beijing     2008        BAROEV, Khasan
#
# [29216 rows x 3 columns]

# %%
oo
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 0       Athens     1896   Aquatics         Swimming         HAJOS, Alfred
# 1       Athens     1896   Aquatics         Swimming      HERSCHMANN, Otto
# 2       Athens     1896   Aquatics         Swimming     DRIVAS, Dimitrios
# 3       Athens     1896   Aquatics         Swimming    MALOKINIS, Ioannis
# 4       Athens     1896   Aquatics         Swimming    CHASAPIS, Spiridon
# ...        ...      ...        ...              ...                   ...
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender                       Event Event_gender   Medal
# ...

# %%
oo['NOC']
# Out:
# 0        HUN
# 1        AUT
# 2        GRE
# 3        GRE
# 4        GRE
#         ...
# 29211    GER
# 29212    LTU
# 29213    ARM
# 29214    CUB
# 29215    RUS
# Name: NOC, Length: 29216, dtype: object

# %%
oo[['Edition','City','Athlete','Medal']]
# Out:
#        Edition     City               Athlete   Medal
# 0         1896   Athens         HAJOS, Alfred    Gold
# 1         1896   Athens      HERSCHMANN, Otto  Silver
# 2         1896   Athens     DRIVAS, Dimitrios  Bronze
# 3         1896   Athens    MALOKINIS, Ioannis    Gold
# 4         1896   Athens    CHASAPIS, Spiridon  Silver
# ...        ...      ...                   ...     ...
# 29211     2008  Beijing        ENGLICH, Mirko  Silver
# 29212     2008  Beijing  MIZGAITIS, Mindaugas  Bronze
# 29213     2008  Beijing       PATRIKEEV, Yuri  Bronze
# 29214     2008  Beijing         LOPEZ, Mijain    Gold
# 29215     2008  Beijing        BAROEV, Khasan  Silver
#
# [29216 rows x 4 columns]

# %%
oo.tail()
# Out:
#           City  Edition      Sport       Discipline               Athlete  \
# 29211  Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko
# 29212  Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas
# 29213  Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri
# 29214  Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain
# 29215  Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan
#
#        NOC Gender       Event Event_gender   Medal
# 29211  GER    Men   84 - 96kg            M  Silver
# 29212  LTU    Men  96 - 120kg            M  Bronze
# 29213  ARM    Men  96 - 120kg            M  Bronze
# 29214  CUB    Men  96 - 120kg            M    Gold
# 29215  RUS    Men  96 - 120kg            M  Silver

# %% [markdown]
# # value_counts()

# %%
oo.Gender.value_counts()
# Out:
# Men      21721
# Women     7495
# Name: Gender, dtype: int64

# %% [markdown]
# # sort_values()

# %%
oo.Edition.sort_values()
# Out:
# 0        1896
# 97       1896
# 98       1896
# 99       1896
# 100      1896
#          ...
# 27847    2008
# 27846    2008
# 27845    2008
# 27858    2008
# 29215    2008
# Name: Edition, Length: 29216, dtype: int64

# %%
oo.sort_values(by=['Edition','Athlete'])
# Out:
#           City  Edition       Sport    Discipline  \
# 7       Athens     1896    Aquatics      Swimming
# 82      Athens     1896  Gymnastics   Artistic G.
# 110     Athens     1896  Gymnastics   Artistic G.
# 111     Athens     1896  Gymnastics   Artistic G.
# 48      Athens     1896     Cycling  Cycling Road
# ...        ...      ...         ...           ...
# 28095  Beijing     2008  Equestrian      Dressage
# 28819  Beijing     2008     Sailing       Sailing
# 28977  Beijing     2008   Taekwondo     Taekwondo
# 28387  Beijing     2008  Gymnastics   Rhythmic G.
# 29007  Beijing     2008      Tennis        Tennis
#
#                               Athlete  NOC Gender                 Event  \
# 7                    ANDREOU, Joannis  GRE    Men       1200m freestyle
# 82           ANDRIAKOPOULOS, Nicolaos  GRE    Men         rope climbing
# 110          ANDRIAKOPOULOS, Nicolaos  GRE    Men   team, parallel bars
# ...

# %% [markdown]
# # Boolean indexing

# %%
oo.Medal == 'Gold'
# Out:
# 0         True
# 1        False
# 2        False
# 3         True
# 4        False
#          ...
# 29211    False
# 29212    False
# 29213    False
# 29214     True
# 29215    False
# Name: Medal, Length: 29216, dtype: bool

# %%
oo[(oo.Medal == 'Gold') & (oo.Gender == 'Women')]
# Out:
#            City  Edition          Sport       Discipline  \
# 417       Paris     1900           Golf             Golf
# 641       Paris     1900         Tennis           Tennis
# 649       Paris     1900         Tennis           Tennis
# 710    St Louis     1904        Archery          Archery
# 713    St Louis     1904        Archery          Archery
# ...         ...      ...            ...              ...
# 29134   Beijing     2008  Weightlifting    Weightlifting
# 29147   Beijing     2008      Wrestling  Wrestling Free.
# 29155   Beijing     2008      Wrestling  Wrestling Free.
# 29163   Beijing     2008      Wrestling  Wrestling Free.
# 29171   Beijing     2008      Wrestling  Wrestling Free.
#
#                      Athlete  NOC Gender  \
# 417    ABBOTT, Margaret Ives  USA  Women
# 641        COOPER, Charlotte  GBR  Women
# 649        COOPER, Charlotte  GBR  Women
# 710    HOWELL, Matilda Scott  USA  Women
# 713    HOWELL, Matilda Scott  USA  Women
# ...

# %% [markdown]
# # String Handling

# %%
oo[oo.Athlete.str.contains('Florence')]
# Out:
#                         City  Edition      Sport      Discipline  \
# 1843                  London     1908    Skating  Figure skating
# 1848                  London     1908    Skating  Figure skating
# 4173                   Paris     1924   Aquatics        Swimming
# 8162                Helsinki     1952  Athletics       Athletics
# 9060   Melbourne / Stockholm     1956  Athletics       Athletics
# 10849                  Tokyo     1964  Athletics       Athletics
# 16817            Los Angeles     1984  Athletics       Athletics
# 18287                  Seoul     1988  Athletics       Athletics
# 18305                  Seoul     1988  Athletics       Athletics
# 18347                  Seoul     1988  Athletics       Athletics
# 18374                  Seoul     1988  Athletics       Athletics
#
#                                Athlete  NOC Gender                   Event  \
# 1843                   SYERS, Florence  GBR  Women              individual
# ...

# %%
oo[oo.Athlete.str.contains('OWENS, Jesse')]
# Out:
#         City  Edition      Sport Discipline       Athlete  NOC Gender  \
# 6427  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6439  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6456  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
# 6523  Berlin     1936  Athletics  Athletics  OWENS, Jesse  USA    Men
#
#              Event Event_gender Medal
# 6427          100m            M  Gold
# 6439          200m            M  Gold
# 6456  4x100m relay            M  Gold
# 6523     long jump            M  Gold

# %%
bgm = oo[(oo.Medal == 'Gold') & (oo.Gender == 'Men') & (oo.Sport == 'Badminton')] 
bgm.sort_values(by=['Athlete'])
# Out:
#             City  Edition      Sport Discipline                  Athlete  NOC  \
# 20045  Barcelona     1992  Badminton  Badminton        BUDI KUSUMA, Alan  INA
# 23701     Sydney     2000  Badminton  Badminton            GUNAWAN, Tony  INA
# 25718     Athens     2004  Badminton  Badminton             HA, Tae-Kwon  KOR
# 25734     Athens     2004  Badminton  Badminton          HIDAYAT, Taufik  INA
# 21787    Atlanta     1996  Badminton  Badminton  HOYER-LARSEN, Poul Erik  DEN
# 23717     Sydney     2000  Badminton  Badminton              JI, Xinpeng  CHN
# 27725    Beijing     2008  Badminton  Badminton             KIDO, Markis  INA
# 25719     Athens     2004  Badminton  Badminton           KIM, Dong Moon  KOR
# 21773    Atlanta     1996  Badminton  Badminton           KIM, Dong Moon  KOR
# 20031  Barcelona     1992  Badminton  Badminton            KIM, Moon-Soo  KOR
# 27727    Beijing     2008  Badminton  Badminton             LEE, Yongdae  KOR
# ...

# %%
rec = oo[oo.Edition >= 1984]
rec.NOC.value_counts().head(3)
# Out:
# USA    1837
# AUS     762
# GER     691
# Name: NOC, dtype: int64

# %%
m = oo[(oo.Medal == 'Gold') & (oo.Gender == 'Men') & (oo.Event == '100m')] 
m.sort_values('Edition',ascending=False)[['City','Edition','Athlete','NOC']]
# Out:
#                         City  Edition                Athlete  NOC
# 27552                Beijing     2008            BOLT, Usain  JAM
# 25539                 Athens     2004         GATLIN, Justin  USA
# 23521                 Sydney     2000        GREENE, Maurice  USA
# 21598                Atlanta     1996        BAILEY, Donovan  CAN
# 19859              Barcelona     1992      CHRISTIE, Linford  GBR
# 18284                  Seoul     1988            LEWIS, Carl  USA
# 16794            Los Angeles     1984            LEWIS, Carl  USA
# 15374                 Moscow     1980           WELLS, Allan  GBR
# 14069               Montreal     1976       CRAWFORD, Hasely  TRI
# 12902                 Munich     1972         BORZOV, Valery  URS
# 11865                 Mexico     1968       HINES, James Ray  USA
# 10823                  Tokyo     1964          HAYES, Robert  USA
# 9924                    Rome     1960            HARY, Armin  EUA
# ...

# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fo = oo[oo.Edition == 1896]
fo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
fo.Sport.value_counts().plot(figsize=(10,5));

# %%
fo.Sport.value_counts().plot(kind='bar');

# %%
fo.Sport.value_counts().plot(kind='barh', color='green');

# %%
fo.Sport.value_counts().plot(kind='pie');

# %% [markdown]
# # Seaborn basic plotting

# %%
import seaborn as sns

# %% [markdown]
# How many medals have been won by men and women in the history of olympics? How many gold, bronze and silver medals were won for each gender?

# %%
sns.countplot(x='Medal',data=oo, hue='Gender');

# %% [markdown]
# Plot the number of medals achieved by Chinese team(Men and Women) in Beijing 2008
# using
# - Matplotlib
# - Seaborn

# %%
mg = oo[(oo.Edition == 2008) & (oo.NOC == 'CHN')]
mg.Gender.value_counts().plot(kind='bar');

# %%
sns.countplot(data=oo, x='Gender');

# %%
sns.countplot(data=oo, x='Gender', palette='bwr');

# %% [markdown]
# Plot the number of Gold, Silver and Bronze for each gender

# %%
sns.countplot(x='Medal', data=mg, hue= 'Gender');

# %%
sns.countplot(x='Medal', data=mg, hue= 'Gender', palette='bwr', order=['Gold','Silver','Bronze']);

# %% [markdown]
# # Index

# %% [markdown]
# # set_index()

# %% [markdown]
# When we run head() again the index is set to default again. To make Athlete as a default index use inplace=True

# %%
oo.head()
# Out:
#      City  Edition     Sport Discipline             Athlete  NOC Gender  \
# 0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN    Men
# 1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT    Men
# 2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE    Men
# 3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE    Men
# 4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE    Men
#
#                         Event Event_gender   Medal
# 0              100m freestyle            M    Gold
# 1              100m freestyle            M  Silver
# 2  100m freestyle for sailors            M  Bronze
# 3  100m freestyle for sailors            M    Gold
# 4  100m freestyle for sailors            M  Silver

# %%
oo.set_index('City')
# Out:
#          Edition      Sport       Discipline               Athlete  NOC  \
# City
# Athens      1896   Aquatics         Swimming         HAJOS, Alfred  HUN
# Athens      1896   Aquatics         Swimming      HERSCHMANN, Otto  AUT
# Athens      1896   Aquatics         Swimming     DRIVAS, Dimitrios  GRE
# Athens      1896   Aquatics         Swimming    MALOKINIS, Ioannis  GRE
# Athens      1896   Aquatics         Swimming    CHASAPIS, Spiridon  GRE
# ...          ...        ...              ...                   ...  ...
# Beijing     2008  Wrestling  Wrestling Gre-R        ENGLICH, Mirko  GER
# Beijing     2008  Wrestling  Wrestling Gre-R  MIZGAITIS, Mindaugas  LTU
# Beijing     2008  Wrestling  Wrestling Gre-R       PATRIKEEV, Yuri  ARM
# Beijing     2008  Wrestling  Wrestling Gre-R         LOPEZ, Mijain  CUB
# Beijing     2008  Wrestling  Wrestling Gre-R        BAROEV, Khasan  RUS
#
#         Gender                       Event Event_gender   Medal
# City
# ...

# %%
oo.reset_index(inplace=True)

# %%
oo.head()
# Out:
#    index    City  Edition     Sport Discipline             Athlete  NOC  \
# 0      0  Athens     1896  Aquatics   Swimming       HAJOS, Alfred  HUN
# 1      1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2      2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3      3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4      4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE
#
#   Gender                       Event Event_gender   Medal
# 0    Men              100m freestyle            M    Gold
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %% [markdown]
# # sort_index()

# %%
ss=oo.set_index('Athlete')
ss
# Out:
#                       index     City  Edition      Sport       Discipline  \
# Athlete
# HAJOS, Alfred             0   Athens     1896   Aquatics         Swimming
# HERSCHMANN, Otto          1   Athens     1896   Aquatics         Swimming
# DRIVAS, Dimitrios         2   Athens     1896   Aquatics         Swimming
# MALOKINIS, Ioannis        3   Athens     1896   Aquatics         Swimming
# CHASAPIS, Spiridon        4   Athens     1896   Aquatics         Swimming
# ...                     ...      ...      ...        ...              ...
# ENGLICH, Mirko        29211  Beijing     2008  Wrestling  Wrestling Gre-R
# MIZGAITIS, Mindaugas  29212  Beijing     2008  Wrestling  Wrestling Gre-R
# PATRIKEEV, Yuri       29213  Beijing     2008  Wrestling  Wrestling Gre-R
# LOPEZ, Mijain         29214  Beijing     2008  Wrestling  Wrestling Gre-R
# BAROEV, Khasan        29215  Beijing     2008  Wrestling  Wrestling Gre-R
#
# ...

# %%
ss.sort_index(inplace=True)
ss.head()
# Out:
#                           index     City  Edition       Sport   Discipline  \
# Athlete
# AABYE, Edgar                651    Paris     1900  Tug of War   Tug of War
# AALTONEN, Arvo Ossian      2849  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Arvo Ossian      2852  Antwerp     1920    Aquatics     Swimming
# AALTONEN, Paavo Johannes   7716   London     1948  Gymnastics  Artistic G.
# AALTONEN, Paavo Johannes   7730   London     1948  Gymnastics  Artistic G.
#
#                           NOC Gender              Event Event_gender   Medal
# Athlete
# AABYE, Edgar              ZZX    Men         tug of war            M    Gold
# AALTONEN, Arvo Ossian     FIN    Men  200m breaststroke            M  Bronze
# AALTONEN, Arvo Ossian     FIN    Men  400m breaststroke            M  Bronze
# AALTONEN, Paavo Johannes  FIN    Men       pommel horse            M    Gold
# AALTONEN, Paavo Johannes  FIN    Men   team competition            M    Gold

# %% [markdown]
# # iloc()

# %% [markdown]
# It is used to get the information at particular index

# %%
oo.iloc[1700]
# Out:
# index                    1700
# City                   London
# Edition                  1908
# Sport                 Sailing
# Discipline            Sailing
# Athlete         RABOT, Pierre
# NOC                       FRA
# Gender                    Men
# Event                      6m
# Event_gender                X
# Medal                  Bronze
# Name: 1700, dtype: object

# %% [markdown]
# OR
# If we want to access multiple rows...

# %%
oo.iloc[[1400,344,1248,3455]]
# Out:
#       index     City  Edition       Sport     Discipline  \
# 1400   1400   London     1908  Gymnastics    Artistic G.
# 344     344    Paris     1900     Cycling  Cycling Track
# 1248   1248   London     1908   Athletics      Athletics
# 3455   3455  Antwerp     1920  Gymnastics    Artistic G.
#
#                        Athlete  NOC Gender              Event Event_gender  \
# 1400          LEHMUSTO, Heikki  FIN    Men   team competition            M
# 344          HILDEBRAND, Louis  FRA    Men      25 kilometres            M
# 1248          WALSH, Cornelius  CAN    Men       hammer throw            M
# 3455  RYDSTRÖM, Arthur Nicolai  NOR    Men  team, free system            M
#
#        Medal
# 1400  Bronze
# 344   Silver
# 1248  Bronze
# 3455  Silver

# %%
oo.iloc[1:5]
# Out:
#    index    City  Edition     Sport Discipline             Athlete  NOC  \
# 1      1  Athens     1896  Aquatics   Swimming    HERSCHMANN, Otto  AUT
# 2      2  Athens     1896  Aquatics   Swimming   DRIVAS, Dimitrios  GRE
# 3      3  Athens     1896  Aquatics   Swimming  MALOKINIS, Ioannis  GRE
# 4      4  Athens     1896  Aquatics   Swimming  CHASAPIS, Spiridon  GRE
#
#   Gender                       Event Event_gender   Medal
# 1    Men              100m freestyle            M  Silver
# 2    Men  100m freestyle for sailors            M  Bronze
# 3    Men  100m freestyle for sailors            M    Gold
# 4    Men  100m freestyle for sailors            M  Silver

# %% [markdown]
# Plot the total number of medals awarded at each of the Olympic games throughout the history

# %%
oo.Edition.value_counts().plot(kind='bar', figsize=(15,10));

# %%
oo.Edition.value_counts().sort_index().plot();

# %% [markdown]
# # Groupby

# %% [markdown]
# # - Groupby object

# %%
oo.groupby('Edition')

# %%
type(oo.groupby('Edition'))
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
list(oo.groupby('Edition'))
# Out:
# [(1896,
#        index    City  Edition          Sport       Discipline  \
#   0        0  Athens     1896       Aquatics         Swimming
#   1        1  Athens     1896       Aquatics         Swimming
#   2        2  Athens     1896       Aquatics         Swimming
#   3        3  Athens     1896       Aquatics         Swimming
#   4        4  Athens     1896       Aquatics         Swimming
#   ..     ...     ...      ...            ...              ...
#   146    146  Athens     1896  Weightlifting    Weightlifting
#   147    147  Athens     1896  Weightlifting    Weightlifting
#   148    148  Athens     1896      Wrestling  Wrestling Gre-R
#   149    149  Athens     1896      Wrestling  Wrestling Gre-R
#   150    150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                         Athlete  NOC Gender                        Event  \
#   0               HAJOS, Alfred  HUN    Men               100m freestyle
# ...

# %% [markdown]
# # Iterating through groups

# %%
for group_key, group_value in oo.groupby('Edition'):
    print(group_key)
    print(group_value)
# Out:
# 1896
#      index    City  Edition          Sport       Discipline  \
# 0        0  Athens     1896       Aquatics         Swimming
# 1        1  Athens     1896       Aquatics         Swimming
# 2        2  Athens     1896       Aquatics         Swimming
# 3        3  Athens     1896       Aquatics         Swimming
# 4        4  Athens     1896       Aquatics         Swimming
# ..     ...     ...      ...            ...              ...
# 146    146  Athens     1896  Weightlifting    Weightlifting
# 147    147  Athens     1896  Weightlifting    Weightlifting
# 148    148  Athens     1896      Wrestling  Wrestling Gre-R
# 149    149  Athens     1896      Wrestling  Wrestling Gre-R
# 150    150  Athens     1896      Wrestling  Wrestling Gre-R
#
#                       Athlete  NOC Gender                        Event  \
# 0               HAJOS, Alfred  HUN    Men               100m freestyle
# 1            HERSCHMANN, Otto  AUT    Men               100m freestyle
# ...

# %% [markdown]
# # Groupby computations

# %%
oo.groupby('Edition').size()
# Out:
# Edition
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# dtype: int64

# %% [markdown]
# # agg([..])

# %%
oo.groupby(['Edition','NOC','Medal']).agg('count')
# Out:
#                     index  City  Sport  Discipline  Athlete  Gender  Event  \
# Edition NOC Medal
# 1896    AUS Gold        2     2      2           2        2       2      2
#         AUT Bronze      2     2      2           2        2       2      2
#             Gold        2     2      2           2        2       2      2
#             Silver      1     1      1           1        1       1      1
#         DEN Bronze      3     3      3           3        3       3      3
# ...                   ...   ...    ...         ...      ...     ...    ...
# 2008    UZB Silver      2     2      2           2        2       2      2
#         VEN Bronze      1     1      1           1        1       1      1
#         VIE Silver      1     1      1           1        1       1      1
#         ZIM Gold        1     1      1           1        1       1      1
#             Silver      3     3      3           3        3       3      3
#
#                     Event_gender
# ...

# %% [markdown]
# # agg({: [..]})

# %%
oo.groupby(['Edition','NOC','Medal']).agg({'Edition' :['count']})
# Out:
#                    Edition
#                      count
# Edition NOC Medal
# 1896    AUS Gold         2
#         AUT Bronze       2
#             Gold         2
#             Silver       1
#         DEN Bronze       3
# ...                    ...
# 2008    UZB Silver       2
#         VEN Bronze       1
#         VIE Silver       1
#         ZIM Gold         1
#             Silver       3
#
# [2356 rows x 1 columns]

# %%
oo.loc[oo.Athlete =='LEWIS, Carl'].groupby('Athlete').agg({'Edition':['min','max','count']})
# Out:
#             Edition
#                 min   max count
# Athlete
# LEWIS, Carl    1984  1996    10

# %% [markdown]
# THIS REPRESENTS LEWIS HAS PARTICIPATED IN OLYMPICS FROM 1984 TO 1996 WITH TOTAL NUMBER OF 10 MEDALS.

# %% [markdown]
# Using groupby() plot the total number of medals awarded at each of the olympic games throughout the history

# %%
oo.groupby('Edition').size().plot();

# %% [markdown]
# # stack() and unstack()

# %%
mw = oo[(oo.Edition == 2008) & ((oo.Event == '100m') | (oo.Event == '200m'))]
mw
# Out:
#        index     City  Edition      Sport Discipline  \
# 27551  27551  Beijing     2008  Athletics  Athletics
# 27552  27552  Beijing     2008  Athletics  Athletics
# 27553  27553  Beijing     2008  Athletics  Athletics
# 27554  27554  Beijing     2008  Athletics  Athletics
# 27555  27555  Beijing     2008  Athletics  Athletics
# 27556  27556  Beijing     2008  Athletics  Athletics
# 27569  27569  Beijing     2008  Athletics  Athletics
# 27570  27570  Beijing     2008  Athletics  Athletics
# 27571  27571  Beijing     2008  Athletics  Athletics
# 27572  27572  Beijing     2008  Athletics  Athletics
# 27573  27573  Beijing     2008  Athletics  Athletics
# 27574  27574  Beijing     2008  Athletics  Athletics
#
#                         Athlete  NOC Gender Event Event_gender   Medal
# 27551               DIX, Walter  USA    Men  100m            M  Bronze
# 27552               BOLT, Usain  JAM    Men  100m            M    Gold
# ...

# %%
g = mw.groupby(['NOC','Gender','Discipline','Event']).size()
g
# Out:
# NOC  Gender  Discipline  Event
# JAM  Men     Athletics   100m     1
#                          200m     1
#      Women   Athletics   100m     3
#                          200m     2
# TRI  Men     Athletics   100m     1
# USA  Men     Athletics   100m     1
#                          200m     2
#      Women   Athletics   200m     1
# dtype: int64

# %%
df = g.unstack(['Discipline','Event'])
df
# Out:
# Discipline Athletics
# Event           100m 200m
# NOC Gender
# JAM Men          1.0  1.0
#     Women        3.0  2.0
# TRI Men          1.0  NaN
# USA Men          1.0  2.0
#     Women        NaN  1.0

# %% [markdown]
# # Heatmaps

# %%
lo = oo[oo.Edition == 2008]
lo
# Out:
#        index     City  Edition      Sport       Discipline  \
# 27174  27174  Beijing     2008   Aquatics           Diving
# 27175  27175  Beijing     2008   Aquatics           Diving
# 27176  27176  Beijing     2008   Aquatics           Diving
# 27177  27177  Beijing     2008   Aquatics           Diving
# 27178  27178  Beijing     2008   Aquatics           Diving
# ...      ...      ...      ...        ...              ...
# 29211  29211  Beijing     2008  Wrestling  Wrestling Gre-R
# 29212  29212  Beijing     2008  Wrestling  Wrestling Gre-R
# 29213  29213  Beijing     2008  Wrestling  Wrestling Gre-R
# 29214  29214  Beijing     2008  Wrestling  Wrestling Gre-R
# 29215  29215  Beijing     2008  Wrestling  Wrestling Gre-R
#
#                     Athlete  NOC Gender         Event Event_gender   Medal
# 27174        GALPERIN, Gleb  RUS    Men  10m platform            M  Bronze
# 27175      MITCHAM, Matthew  AUS    Men  10m platform            M    Gold
# ...

# %%
g = lo.groupby(['NOC', 'Medal']).size().unstack('Medal', fill_value=0)
g = g.sort_values(['Gold','Silver','Bronze'], ascending=False)[['Gold','Silver','Bronze']]
g
# Out:
# Medal  Gold  Silver  Bronze
# NOC
# USA     125     109      81
# CHN      74      53      57
# RUS      43      44      56
# GER      42      16      43
# KOR      41      11      26
# ..      ...     ...     ...
# ISR       0       0       1
# MDA       0       0       1
# MRI       0       0       1
# TOG       0       0       1
# VEN       0       0       1
#
# [86 rows x 3 columns]

# %%
sns.heatmap(g)

# %%
g = g.transpose()
g
# Out:
# NOC     USA  CHN  RUS  GER  KOR  NED  AUS  GBR  FRA  JPN  ...  VIE  ARM  TPE  \
# Medal                                                     ...
# Gold    125   74   43   42   41   40   31   31   25   23  ...    0    0    0
# Silver  109   53   44   16   11   18   42   25   23   11  ...    1    0    0
# Bronze   81   57   56   43   26    4   76   21   28   17  ...    0    6    4
#
# NOC     AFG  EGY  ISR  MDA  MRI  TOG  VEN
# Medal
# Gold      0    0    0    0    0    0    0
# Silver    0    0    0    0    0    0    0
# Bronze    1    1    1    1    1    1    1
#
# [3 rows x 86 columns]

# %%
plt.figure(figsize=(16,5))
sns.heatmap(g)
